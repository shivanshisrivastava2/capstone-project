# %%
# !pip install pathway bokeh --quiet # This cell may take a few seconds to execute.
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.6/777.6 kB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.6/244.6 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.1/319.1 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.8/985.8 kB 50.8 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
import pathway as pw
import bokeh.plotting
import panel as pn
from bokeh.models import ColumnDataSource
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f200e8e0-a6a9-4a60-b197-8a0ef533ec84'>
#   <div id="fb4a0ed1-b5c0-4f9c-b4c9-13b08cba9627" data-root-id="f200e8e0-a6a9-4a60-b197-8a0ef533ec84" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.read_csv('/content/dataset.csv')
df

# You can find the sample dataset here: https://drive.google.com/file/d/1D479FLjp9aO3Mg8g6Lpj9oRViWacurA6/view?usp=sharing
# Out:
#           ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy  \
# 0          0      BHMBCCMKT01       577  26.144536  91.736172         61
# 1          1      BHMBCCMKT01       577  26.144536  91.736172         64
# 2          2      BHMBCCMKT01       577  26.144536  91.736172         80
# 3          3      BHMBCCMKT01       577  26.144536  91.736172        107
# 4          4      BHMBCCMKT01       577  26.144536  91.736172        150
# ...      ...              ...       ...        ...        ...        ...
# 18363  18363         Shopping      1920  26.150504  91.733531       1517
# 18364  18364         Shopping      1920  26.150504  91.733531       1487
# 18365  18365         Shopping      1920  26.150504  91.733531       1432
# 18366  18366         Shopping      1920  26.150504  91.733531       1321
# 18367  18367         Shopping      1920  26.150504  91.733531       1180
#
#       VehicleType TrafficConditionNearby  QueueLength  IsSpecialDay  \
# ...

# %%
# Combine the 'LastUpdatedDate' and 'LastUpdatedTime' columns into a single datetime column
df['Timestamp'] = pd.to_datetime(df['LastUpdatedDate'] + ' ' + df['LastUpdatedTime'],
                                  format='%d-%m-%Y %H:%M:%S')

# Sort the DataFrame by the new 'Timestamp' column and reset the index
df = df.sort_values('Timestamp').reset_index(drop=True)

# %%
# Save the selected columns to a CSV file for streaming or downstream processing
df[["SystemCodeNumber", "Timestamp", "Occupancy", "Capacity", "QueueLength", "TrafficConditionNearby", "IsSpecialDay", "VehicleType"]].to_csv("parking_stream.csv", index=False)
#Note: Only three features are used here for simplicity.
# Participants are expected to incorporate additional relevant features in their models.

# %%
class ParkingSchema(pw.Schema):
    Timestamp: str
    SystemCodeNumber: str
    Occupancy: int
    Capacity: int
    QueueLength: int
    TrafficConditionNearby: float
    IsSpecialDay: bool
    VehicleType: str

# %%
data = pw.demo.replay_csv("/content/parking_stream.csv", schema=ParkingSchema, input_rate=1000)

# %%
# Define the datetime format to parse the 'Timestamp' column
fmt = "%Y-%m-%d %H:%M:%S"

# Add new columns to the data stream:
# - 't' contains the parsed full datetime
# - 'day' extracts the date part and resets the time to midnight (useful for day-level aggregations)
data_with_time = data.with_columns(
    t = data.Timestamp.dt.strptime(fmt),
    day = data.Timestamp.dt.strptime(fmt).dt.strftime("%Y-%m-%dT00:00:00")
)

# %%
vehicle_weights = {"car": 1.0, "bike": 0.7, "truck": 1.5}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-17-2196952649.py in <cell line: 0>()
#       1 data_with_weights = data_with_time.with_columns(
# ----> 2     vehicle_weight = pw.choose(
#       3         pw.this.VehicleType == "car", 1.0,
#       4         pw.this.VehicleType == "bike", 0.7,
#       5         pw.this.VehicleType == "truck", 1.5,
#
# AttributeError: module 'pathway' has no attribute 'choose'

# %%
import datetime
@pw.udf
def vehicle_type_weight(vtype: str) -> float:
    return vehicle_weights.get(vtype.lower(), 1.0)

def bool_to_float(value: bool) -> float:
    return 1.0 if value else 0.0


demand_intermediate = (
    data_with_time.with_columns(
        vweight = vehicle_type_weight(pw.this.VehicleType)
    )
    .windowby(
        pw.this.t,
        instance=pw.this.SystemCodeNumber,
        window=pw.temporal.tumbling(datetime.timedelta(minutes=30)),
        behavior=pw.temporal.exactly_once_behavior()
    )
    .reduce(
        lot = pw.reducers.any(pw.this.SystemCodeNumber),
        timestamp = pw.this._pw_window_end,
        occupancy = pw.reducers.avg(pw.this.Occupancy),
        cap = pw.reducers.max(pw.this.Capacity),
        queue = pw.reducers.avg(pw.this.QueueLength),
        traffic = pw.reducers.avg(pw.this.TrafficConditionNearby),
        special = pw.reducers.max(pw.this.IsSpecialDay),
        vtype = pw.reducers.avg(pw.this.vweight),
    )
)
# Step B1: Calculate norm_demand
demand_scored = demand_intermediate.with_columns(
    norm_demand = (
        (pw.this.occupancy / pw.this.cap) +
        0.3 * pw.this.queue -
        0.2 * pw.this.traffic +
        0.4 * pw.this.special +
        0.3 * pw.this.vtype
    )
)

# Step B2: Bound norm_demand and compute price
demand_based = demand_scored.with_columns(
    norm_demand_bounded = pw.if_else(
        (pw.this.norm_demand < 0),
        0,
        pw.if_else(pw.this.norm_demand > 2.0, 2.0, pw.this.norm_demand)
    ),
    model2_price = pw.this.norm_demand_bounded * 10
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-30-3138636496.py in <cell line: 0>()
#      30 )
#      31 # Step B1: Calculate norm_demand
# ---> 32 demand_scored = demand_intermediate.with_columns(
#      33     norm_demand = (
#      34         (pw.this.occupancy / pw.this.cap) +
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _pathway_trace_marker(*args, **kwargs)
#     132             return func(*args, **kwargs)
#     133         except Exception as e:
# --> 134             _reraise_with_user_frame(e)
#     135
#     136     return _pathway_trace_marker
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _reraise_with_user_frame(e, trace)
#      98
#      99     if hasattr(e, "_pathway_trace_note"):
# --> 100         raise e
#     101
#     102     if trace is None:
#
# ...
